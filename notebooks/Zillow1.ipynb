# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
price = pd.read_csv('price.csv')
price_per = pd.read_csv('pricepersqft.csv')

# %%
price.describe()
price =price.transpose()
price.rename()
price.head()
# Out:
#               0            1        2        3             4         5      \
# City Code      6181        12447    17426    39051         13271     40326
# City       New York  Los Angeles  Chicago  Houston  Philadelphia   Phoenix
# Metro      New York  Los Angeles  Chicago  Houston  Philadelphia   Phoenix
# County       Queens  Los Angeles     Cook   Harris  Philadelphia  Maricopa
# State            NY           CA       IL       TX            PA        AZ
#
#                6            7          8                  9      \
# City Code      18959         6915      54296              38128
# City       Las Vegas  San Antonio  San Diego             Dallas
# Metro      Las Vegas  San Antonio  San Diego  Dallas-Fort Worth
# County         Clark        Bexar  San Diego             Dallas
# State             NV           TX         CA                 TX
#
#                 ...                  13121         13122        13123  \
# ...

# %%
price_per.head()
# Out:
#    City Code          City         Metro        County State  Population Rank  \
# 0       6181      New York      New York        Queens    NY                1
# 1      12447   Los Angeles   Los Angeles   Los Angeles    CA                2
# 2      17426       Chicago       Chicago          Cook    IL                3
# 3      39051       Houston       Houston        Harris    TX                4
# 4      13271  Philadelphia  Philadelphia  Philadelphia    PA                5
#
#    November 2010  December 2010  January 2011  February 2011      ...       \
# 0            NaN            NaN           NaN            NaN      ...
# 1          1.578          1.578         1.580          1.582      ...
# 2          1.244          1.248         1.254          1.254      ...
# 3          0.788          0.784         0.784          0.786      ...
# 4          0.854          0.858         0.858          0.858      ...
#
# ...

# %%
plt.plot(range(0,75),price.transpose().ix[5:])
# Out:
# /Users/allegralatimer/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-b43120468ab9> in <module>()
# ----> 1 plt.plot(range(0,75),price.transpose().ix[5:])
#
# /Users/allegralatimer/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# ...
